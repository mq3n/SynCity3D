# %% [markdown]
# # Setup

# %% [markdown]
# ## Clear temporary files

# %%
import shutil, os

path = "./data_coco"
if os.path.exists(path):
    shutil.rmtree(path)
    print("data_coco removed")
# Out:
# data_coco removed
