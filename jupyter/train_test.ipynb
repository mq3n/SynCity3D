# %%
from mmengine.config import Config
from mmdet.registry import RUNNERS

CFG_PATH = 'configs/facade_maskrcnn_test.py'
WORK_DIR = './work_dirs/facade_maskrcnn_test'

cfg = Config.fromfile(CFG_PATH)
cfg.work_dir = WORK_DIR

runner = RUNNERS.build(cfg)
runner.train()
# Out:
# 03/12 23:19:24 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.20 (default, Oct  3 2024, 15:19:54) [MSC v.1929 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1198200428
#     GPU 0: NVIDIA GeForce RTX 4090 Laptop GPU
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v13.1
#     NVCC: Cuda compilation tools, release 13.1, V13.1.80
#     MSVC: n/a, reason: fileno
#     PyTorch: 2.1.2+cu118
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
import json, os

ann = r"data_coco/annotations/instances_train.json"

with open(ann, "r", encoding="utf-8") as f:
    coco = json.load(f)

print("images:", len(coco.get("images", [])))
print("annotations:", len(coco.get("annotations", [])))
print("categories:", coco.get("categories", []))

if coco.get("images"):
    print("first image:", coco["images"][0])

if coco.get("annotations"):
    print("first ann:", coco["annotations"][0])
# Out:
# images: 166
# annotations: 3779
# categories: [{'id': 1, 'name': 'poprawny', 'supercategory': 'object'}]
# first image: {'id': 1, 'file_name': 'x_155_0.png', 'width': 6080, 'height': 3040}
# first ann: {'id': 1, 'image_id': 1, 'category_id': 1, 'segmentation': {'size': [3040, 6080], 'counts': 'PcWW9\\b0b\\...]dP`0'}, 'area': 4407562.0, 'bbox': [3182.0, 267.0, 2725.0, 1956.0], 'iscrowd': 0}

# %%
from mmengine.config import Config
from mmdet.registry import DATASETS

cfg = Config.fromfile("configs/facade_maskrcnn_test.py")
ds = DATASETS.build(cfg.train_dataloader["dataset"])

print("dataset len:", len(ds))
print(ds[0].keys())
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# dataset len: 166
# Jądro Kernel uległo awarii podczas wykonywania kodu w bieżącej komórce lub w poprzedniej komórce.
#
# Przejrzyj kod w komórkach, aby zidentyfikować możliwą przyczynę awarii.
#
# Kliknij <a href='https://aka.ms/vscodeJupyterKernelCrash'>tutaj</a>, aby uzyskać więcej informacji.
#
# Aby uzyskać dalsze szczegóły, wyświetl <a href='command:jupyter.viewOutput'>dziennik</a> Jupyter.

# %%
import json

with open("data_coco/annotations/instances_train.json", "r", encoding="utf-8") as f:
    coco = json.load(f)

print(coco["categories"])
# Out:
# [{'id': 1, 'name': 'poprawny', 'supercategory': 'object'}]
