# %% [markdown]
# # COCO Dataset Export (RLE)
#
# This notebook generates a canonical COCO instance-segmentation dataset from the original RGB mask annotations.
#
# Images (`x_<id>_<angle>`) and corresponding masks (`z_<id>_<angle>`) are paired deterministically and converted into instance annotations using connected components. Segmentations are stored using COCO-compatible run-length encoding (RLE).
#
# The resulting dataset serves as a frozen ground truth for all subsequent experiments and model comparisons.

# %%
# %run ../scripts/export_coco_rle.py
# Out:
# ...
# Exporting instances_test.json: 100%|██████████| 20/20 [00:47<00:00,  2.35s/it]
# Done.
